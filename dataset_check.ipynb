# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import random as rd

# %%
dataset = pd.read_csv("dataset.csv")
dataset.head()
# Out:
#                 img_filename         x         y
# 0  Dataset/1755730134924.jpg  0.468387  0.441178
# 1  Dataset/1755730135181.jpg  0.428871  0.367652
# 2  Dataset/1755730135691.jpg  0.349838  0.220598
# 3  Dataset/1755730136202.jpg  0.268171  0.068642
# 4  Dataset/1755730136711.jpg  0.189138  0.117660

# %%
augmented_dataset = pd.read_csv("augmented_dataset.csv")
augmented_dataset.head()
# Out:
#                           img_filename         x         y
# 0  Augmented_Dataset/1755730134924.jpg  0.468387  0.441178
# 1  Augmented_Dataset/1755730135181.jpg  0.428871  0.367652
# 2  Augmented_Dataset/1755730135691.jpg  0.349838  0.220598
# 3  Augmented_Dataset/1755730136202.jpg  0.268171  0.068642
# 4  Augmented_Dataset/1755730136711.jpg  0.189138  0.117660

# %%
NUM_IMAGES = 5
plt.figure(figsize=(30, 18))  # Increased figure size for bigger images
for i in range(NUM_IMAGES):
    img_path, x, y = dataset.iloc[rd.randint(0, len(dataset))]
    
    # mirror x and y
    x = 1 - x
    y = 1 - y

    # Image
    img = plt.imread(img_path)
    
    plt.subplot(NUM_IMAGES, 2, 2*i+1)
    plt.imshow(img)
    plt.title(f"{img_path}", fontsize=14)  # Increased font size

    # Target (x, y) in a 1×1 square
    ax = plt.subplot(NUM_IMAGES, 2, 2*i+2)
    ax.plot(x, y, 'ro', markersize=10)  # Increased marker size

    # keep the limits fixed at [0, 1] even after enforcing square aspect
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect('equal', adjustable='box')

    # optional: show only the 0 and 1 ticks
    ax.set_xticks([0, 1])
    ax.set_yticks([0, 1])

    ax.set_title(f"Target {x:.2f} {y:.2f}", fontsize=14)  # Increased font size

plt.tight_layout(pad=4.0)  # Increased padding for better spacing
plt.show()

# %%
NUM_IMAGES = 5
plt.figure(figsize=(30, 18))  # Increased figure size for bigger images
for i in range(NUM_IMAGES):
    img_path, x, y = augmented_dataset.iloc[rd.randint(0, len(augmented_dataset))]
    
    # mirror x and y
    x = 1 - x
    y = 1 - y

    # Image
    img = plt.imread(img_path)
    
    plt.subplot(NUM_IMAGES, 2, 2*i+1)
    plt.imshow(img)
    plt.title(f"{img_path}", fontsize=14)  # Increased font size

    # Target (x, y) in a 1×1 square
    ax = plt.subplot(NUM_IMAGES, 2, 2*i+2)
    ax.plot(x, y, 'ro', markersize=10)  # Increased marker size

    # keep the limits fixed at [0, 1] even after enforcing square aspect
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect('equal', adjustable='box')

    # optional: show only the 0 and 1 ticks
    ax.set_xticks([0, 1])
    ax.set_yticks([0, 1])

    ax.set_title(f"Target {x:.2f} {y:.2f}", fontsize=14)  # Increased font size

plt.tight_layout(pad=4.0)  # Increased padding for better spacing
plt.show()
